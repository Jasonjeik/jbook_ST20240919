# %% [markdown]
# # Examen Final

# %% [markdown]
# **Maestría**
#     Análitica de Datos
#
# **Asignatura**
#     Serie de tiempo
#
# **Periodo**
#     2024-03

# %% [markdown]
# **Miembros:**
#     Barrios Jason
#     Gomez Karen
#     Giraldo Isabella
